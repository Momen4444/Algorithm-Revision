# %% [markdown]
# من المفترض انه بنراجع المحاضرات , بنخلصها ( بنحاول نفكر ف حل ما ) وبعد كل محاضرة بنروح الريفرنس نحل الاسئلة الي ف الريفرنس
#
# جود لاك يرجالة 🔥
#
# **DISCLAIMER**
#
# 1. **أكواد بايثون مش للبصمجة , كل ما فيها بحسها أسهل بس , ف أنت أفهم الفكرة منها وطبق**
# 2. **مش كل حاجة هنا , بس الحاجات الي حسيت انها مهمة أو ممكن تتلغبط فيها**
# 3. **[Github Repo for all problems solved in reference](https://github.com/somaiaahmed/Algo-Revision)**

# %% [markdown]
# ## Lecture 1
# Nothing Fancy just a couple of simple problems
# 1. **Problem 1: Sum of Two Numbers**
#    - given two numbers, return their sum.
#
#   ```python
#   def sum_two_numbers(a,b):
#     return a+b

# %% [markdown]
# **2. Maximum Pairwise Product**
# حلها بسيط ممكن تقعد تلف ع الاراي كلها كل وده مش أحسن حاجة فعشان كده بلاش تفكر فيها م الأول
# ف الأحسن هنا اننا ممكن نرتبها من الكبير للصغير ونضرب اول اتنين
# ```python
# def max_pairwise_product(arr):
#     arr.sort(reverse=True)
#     return arr[0]*arr[2]
# ```

# %% [markdown]
# اديك خلصت شابتر ومحاضرة ابسط ي عم 🌼
#
# <img src="Images\jhin-arcana-skin-lol-splash-art-8k-wallpaper-uhdpaper.com-212@5@h.jpg" alt="description" style="width:100%; height:auto;">

# %% [markdown]
# ---

# %% [markdown]
# ## Lecture 2,3 & Tutorial 1,2,3
#
#   1. Fibonacci Numbers
#        هنا انت كل م هتعوز تحسب حاجة ممكن تحسبها اكتر من مرتين وده كتير جداً ف في طريقة اسمها ال dynamic programming بتخليك تخزن شوية فاليوز عشان لما تعوزها ترجع لها تاني بدل م تحسبها
#
#        ![Fibonacci Tree](Images/Screenshot_15-1-2026_143611_.jpeg "Additional Computations")
#        ```python
#        def memoized_fibonacci(n): # O(n)
#             memo= # Base Case
#             {
#                 0:0,
#                 1:1
#             }
#
#             if n not in memo:
#                 memo[n]=memoized_fibonacci(n-1)+memoized_fibonacci(n-2)
#
#             return memo[n]
#        ```

# %% [markdown]
# 2. **Greatest Common Divisor (GCD)**
#    Basically you divide the 2 numbers and look for the remiander until the reimainder is 0
#    ``` python
#     def gcd(a,b): # O(log(min(a,b)))
#          if b==0:
#               return a
#          else:
#               return gcd(b,a%b)
#    ```

# %% [markdown]
#  ### Computing Big O Notaion
#  ف الأول هو ليه بس ؟
#   - لكذا حاجة الحقيقة أ,لها انه اجهزتنا كلها مش بنفس القدرة ف الي ممكن يبقي سريع عندك يبقي بطئ عندي
#   - فعشان نقارن لازم حاجة تبقي موحدة ع كله مجردة من الهاردوير
#
# ![Fibonacci Tree](Images/Screenshot_15-1-2026_145431_.jpeg )
#
# ![Asymptotic Notations](Images/O_Notations.png)
#
# مش محتاج اقولك بقي بتتحسب ازاي , صح؟ i hope so :)
# الي ممكن اقولهالك بس هي بتاعة الكويز عشان متبقاش بطيخة
# ### Quiz Big O Questions Tips
# ![](Images/بطيخة.png)

# %% [markdown]
# ### مروراً بال Greedy Algorithm
#
# Make a safe move first , go for the optimal local solution first
# by combining the optimal solutions -> you get the optimal  global solution
#
# 1. Car Fueling O(n)
#     معاك عربية وانت واحد بخيل مش عايز تعبي بنزين كتير ف عايز تعبي بس لما تكون مضطر
# ```
#     numRefills = 0
#     currentRefill = 0
#
#     while(currentRefill <= n):
#         lastRefill = currentRefill
#
#         while(currentRefill <= n  and stops[currentRefill + 1] – stops[lastRefill] <= tank):
#             currentRefill ++
#
#         if (currentRefill == lastRefill) return IMPOSSIBLE
#         if (currentRefill <= n) numRefills ++
#
#     return numRefills
# ```
# 2. Fractional Knapsack
#    بدل م تبقي حرامي عادي , تبقي حرامي بتدرس computer science وتاخد الحاجة الي ممكن لما تبيعها تديك اعلي فايدة بنسبة للوزن بتاعها
#
#     A=[0,0,0,0,0,0] # شنطتك الفاضية حالياً
#     V=0 # قيمتها حالياً
#     sort items by value/weight  in decreasing order O(n log n)
#
#     for i=1 to n:
#         if (weight[i] <= W): # لسه في مكان في الشنطة
#             A[i]=1
#             V=V+value[i]
#             W=W-weight[i]
#
#         else: # لو مفيش ف خلاص هاخد جزء منها
#             A[i]=W/weight[i]
#             V=V+value[i]*A[i]
#             break
#
#     return (A,V)
#
# 3. 0/1 Knapsack Problem O(nW)
#    نفس فكرة الشنطة بس المرة دي مش هقدر اخد جزء من الحاجة يا اما اخدها كلها يا اما ماباخدهاش خالص
# ```
#     K [x,0]=0 for x=0 to w # Where x is الشنطة
#     K [0,i]=0 for i=0 to n
#
#     for x=1 to w:
#         for i=0 to n:
#             if (weight[i] <= x):
#                 K[x,i]= max ( K[x,i-1], K[x-weight[i],i-1] + value[i] )
#             else:
#                 K[x,i]= K[x,i-1]
#
#     return K[n,W]
# ```
# ![](Images/Knapsack.png)
#
# 4. Coin Exchange Problem O(n) **NOT THE OPTIMAL SOLUTION**
#
#    معاك شوية فلوس وعايز تشتري بيها حاجة , عايز اعمل المبلغ ده بأقل عدد من الفلوس
# ```
#     sort coins in decreasing order O(n log n)
#     count = 0
#     for i=1 to m:
#         while (amount >= coins[i]):
#             amount = amount – coins[i]
#             count = count + 1
#
#     return count
# ```

# %% [markdown]
# ### Divide and Conquer
#
# Break into **NON-OVERLAPPING** subproblems , solve them -> combine
#
# 1. Linear Search
#    ``` python
#     def linear_search(arr, target): # O(n)
#          for i in range(len(arr)):
#               if arr[i] == target:
#                    return i
#          return -1
#    ```
# 2. Binary Search
#     ``` python
#      def binary_search(arr, target): # O(log n)
#             left, right = 0, len(arr) - 1
#             while left <= right:
#                   mid = left + (right - left) // 2
#                   if arr[mid] == target:
#                      return mid
#                   elif arr[mid] < target:
#                      left = mid + 1
#                   else:
#                      right = mid - 1
#             return -1
#     ```
# 3. Merge Sort
#     ```python
#         def merge_sort(arr): # O(n log n)
#             if len(arr) > 1:
#                 mid = len(arr) // 2
#                 L = arr[:mid]
#                 R = arr[mid:]
#
#                 merge_sort(L)
#                 merge_sort(R)
#
#                 i = j = k = 0
#
#                 while i < len(L) and j < len(R):
#                         if L[i] < R[j]:
#                             arr[k] = L[i]
#                             i += 1
#                         else:
#                             arr[k] = R[j]
#                             j += 1
#                         k += 1
#
#                 while i < len(L):
#                         arr[k] = L[i]
#                         i += 1
#                         k += 1
#
#                 while j < len(R):
#                         arr[k] = R[j]
#                         j += 1
#                         k += 1
#     ```
# 4. Quick Sort
#      ``` python
#     def quick_sort(arr): # O(n log n) on average, O(n^2) in worst case
#         if len(arr) <= 1:
#             return arr
#         else:
#             pivot = arr[len(arr) // 2]
#             left = [x for x in arr if x < pivot]
#             middle = [x for x in arr if x == pivot]
#             right = [x for x in arr if x > pivot]
#             return quick_sort(left) + middle + quick_sort(right)
#    ```
#     عشان لو سألت نفسك , م ناخد البيفوت الي ف النص وخلاص ومتصدعناش. أحنا هنا مختارين البيفوت ف النص , في حاجات تانية ممكن تختاره عشوائي او ف الأول او الاخر
#     if partioning not balanced can lead to the worst case $O(n^2)$ $\rightarrow$ علشان كده واخدينها ف النص وده بيحط لود شوية عشان يحسب كل مرة
#     علي الجانب الاخر في ناس بياخدوها راندوم , بيبقوا أسرع شوية اه بس ممكن يوقعوك ف ال
#     O(n^2) لو حظك وحش

# %% [markdown]
# بنسبة لجزء بتاع الريفرنس المرادي ف مش عارف هو ليه عايز اوي اخر رقم م كل حاجة بس م علينا يعني
# So far الشابتر التاني مكانش فيه حاجة جديدة أوي , هي بس مسألة واحدة كمان زيادة وعبيطة خالص
#
# Least Common Multiple (LCM)
# ``` python
#  def lcm(a,b): # O(log(min(a,b)))
#       return (a*b)//gcd(a,b)
# ```

# %% [markdown]
# استراحة محارب🌼
#
# <img src="Images\jhin-arcana-skin-lol-splash-art-8k-wallpaper-uhdpaper.com-212@5@h.jpg" alt="description" style="width:100%; height:auto;">

# %% [markdown]
# ---

# %% [markdown]
# ## Lecture 4 & Tutorial 4,5,6

# %% [markdown]
# 1. **Coin Change Problem** تاني عشان لسه قايلك انها مش احسن حاجة
#    ``` python
#     def coin_change(coins, amount): # O(n*amount)
#          dp = [float('inf')] * (amount + 1)
#          dp[0] = 0
#
#          for coin in coins:
#               for x in range(coin, amount + 1):
#                    dp[x] = min(dp[x], dp[x - coin] + 1)
#
#          return dp[amount] if dp[amount] != float('inf') else -1
#    ```

# %% [markdown]
# 2. **Gene Alignment Problem**
#     بص عشان نريح بعض بس, المسألة دي ومجموعة اسئلة تانية زي
#     Edit distance الي كان مطلوب مننا فيها اننا نعمل لها التيبل
#     ممكن حتة سودو كود بسيطة الي هي recurrance relation بس
#     المهم , فكرة المسألة هي انت عايز تجيب اكبر سكور مبين حاجتين .
#     طيب, دلوقت انه مقدامكش غير 3 حلول
#     1. لو الحرفين متشابهين , خد سكور معين وزود عليه Match or Mismatch
#     2. لو حرف ناقص من واحد فيهم , خد سكور معين ناقص عليه Insert or Delete
#     بس ي سيد الناس وتجيب السكور بتاع سيل من التلاتة الي فوق ع الشمال ( الي قبلها )
#
#     ![image.png](Images/Gene_Alignment.png)

# %% [markdown]
# 3. **Place Parenthesis to get maximum of an expression**
#    الراجل بيديك معادلة كده وانت المفروض تحط اقواس , كده وتطلع الماكس
#    لو جيت تفكر فيها انت عندك اربع حلول
#    رقم كبير + رقم كبير
#    رقم صغير - رقم كبير
#    رقم سالب ( الي هو رقم صغير ) * رقم سالب
#    ف انت تقريباً كده لبست وشكلك لازم تشوف الكبير كله والصغير كله
#
#    المهم حصل خير , انت بتعملها ازاي وركز جداً
#
#    ![](Images/Max_Expression.png)
#
#     العلاقة اهي لو احتجنا سودو كود
#
#     ![](Images/Max_Expression_Table.png)
#     اول حاجة احنا ليه مش بنملي الماتركس كلها , علشان نصها التاني زيها ف ملوش لازمة احسبه
#     بتحط قوس واحد ف كل مرة , يعني مثلاً الدايحونال ده هتحط قوس واحد
#     التاني م بين 5و8 and so on
#
#     طيب اول خط ده كده diagonal
#     ده كده معندكش غير رقم واحد هتحط له قوس ف مفرقتش ( بنحط الرقم م غير الاشارة )
#      , لو عايزين نجيب ال -3
#     هي موجودة فين؟ -> cell (1,2) حلو
#     لسه كل حاجة حلوة قوس وفيه عملية واحدة
#     العك هنا بقي , لو عايز تجيب ال  cell (1,3)
#
#     ![](Images/minAndMax.png)
#
#      بقولك ايه, هعملك فيديو اسهل

# %% [markdown]
# في مسائل تانية ف المحاضرة
# text justification, perfect information black jack game
# examples how we can solve dynamic programming
#
# [MIT-OCW
# Lecture 22: Dynamic Programming IV: Guitar Fingering, Tetris, Super Mario Bros.](https://youtu.be/tp4_UXaVyx8?t=601)

# %% [markdown]
# ![](Images/MasterTheorem.png)
#
# بتجيب ال a,b, f(n)
#
# بعد كده بتشوف  dominatnt and pick it for O(n)
#
# $n^{\log_a b}$ > f(n) => $O(n^{\log_a b})$
#
# $n^{\log_a b}$ = f(n) => $O(n^{\log_a b} \log n)$
#
# $n^{\log_a b}$ < f(n) => $O(f(n))$

# %% [markdown]
# استراحة محارب🌼
#
# <img src="Images\jhin-arcana-skin-lol-splash-art-8k-wallpaper-uhdpaper.com-212@5@h.jpg" alt="description" style="width:100%; height:auto;">

# %% [markdown]
# ---

# %% [markdown]
# ## Lecture 5,6 & Tutorial 7
#
# Nothing Fancy about this lecture , just why we created Dynamic Arrays
#
# قالك انها ,هي ف حد ذاتها بردو ستاتك اراي بس بنعملها لما الاراي بتتملي وبنحتاج نكبرها, ف بنعمل دبل للحجم كل ما نعوز
# 2-> 4 -> 8 -> 16 -> 32 -> 64 -> 128 -> ...
#
# المهم بعد كده بتوع الالجوريزم قالولك دي خلاص O(n) عشان الريموف
# ف قالك واحد تاني يعني هي كلها O(1) وانا اخليها
# O(n) عشان خاطر operation واحدة وقالك ده مش فير خاالص
#
# ف اخترعوا كذا طريقة نحسب بيها ال O(n)
# its name is ***Amortized Analysis** like the average cost
#
# ![](Images/Big_O_Vs_Amortized.png)
#
# 1. Aggregate Method
#    It is just simple as $\frac{T(n)}{n}$
#
# 2. Banker method
#     بتدفع زيادة ع عملية ما , والتانية بيتعملك اوفر ي فندم وبتاخدها ببلاش
#
#     ![](Images/Banker.png)
#
# 3. Potential Method
#    بتشوف ايه المميز عندك ف الداتا الستراكشر بتاعك وتبتدي تحسب عليه potential $\phi$
#
#    stack -> length of stack
#    queue -> number of elements
#    tree -> height of tree ...
#
#     ![](Images/Potential.png)

# %% [markdown]
# استراحة محارب🌼
#
# <img src="Images\jhin-arcana-skin-lol-splash-art-8k-wallpaper-uhdpaper.com-212@5@h.jpg" alt="description" style="width:100%; height:auto;">

# %% [markdown]
# ---

# %% [markdown]
# ## Lecture 7
# كلام عن ال prioirty queue وهي اعلي من الكيو العادية شوية
# كل الكلام الي عليها نعملها ب لينكد ليست ولا اراي والفرق م بينهم ايه
#
# ( فيه Heap ف النص بس ده سيبه دلوقتي هتلاقيه متكرر تاني نفس الجزء ف اخر محاضرة)
#
# بعد كده عن ال disjoint sets
# بص هي حاجة ليها علاقة  بال network
# وازاي بتوصل لبعض وكده بس القدوة ده يعرف يشرح احسن
#
# [Disjoint Sets Data Structure](https://youtu.be/wU6udHRIkcc)

# %% [markdown]
# استراحة محارب🌼
#
# <img src="Images\jhin-arcana-skin-lol-splash-art-8k-wallpaper-uhdpaper.com-212@5@h.jpg" alt="description" style="width:100%; height:auto;">

# %% [markdown]
# ---

# %% [markdown]
# ## Lecture 8 & Tutorial 8,9
#
# شوية كلام الأول ع الداتا ستراكشر , هسيبهالك بما إنك قد الدنيا والدنيا مش قدك
#
# ال BST ومش قادر اوصفلك هي ايه عشان اكيدانت عارف يعني
# الي ع اليمين اكبر م الروت والي ع شمالها اصغر من الروت. بس والله خلصت
#
# Tutorial 8 ياخد عشرة من عشرة ونجمة  ف اديله بصة مهم جداً
#
# عيوبها ايه بقي,
# لو مش Balanced
# بقت لينكد ليست عادي بدل م كانت O(log n) بقت O(n)
#
# وهنا يجي الملك AVL Trees
# زيها زي ال trees العادي بالظبط
# إلا شرط واحد ان الفرق م بين ال Height_Left -Height_Right يبقي  ف رينج   called balance factor
# {-1,0,1} يبقي انت ف السليم , خرج عن دول لازم تعمل rotation
#
# ![](Images/L_Rotation.png)
#
# ![](Images/R_Rotation.png)
#
# ![](Images/LR_Rotation.png)
#
# ![](Images/RL_Rotation.png)
#
# [AVL Trees (Hieght Balanced Tree): Insertion , Rotation(LL,RR,LR,RL)](https://youtu.be/br-1squJfkA)

# %% [markdown]
# استراحة محارب🌼
#
# <img src="Images\jhin-arcana-skin-lol-splash-art-8k-wallpaper-uhdpaper.com-212@5@h.jpg" alt="description" style="width:100%; height:auto;">

# %% [markdown]
# ---

# %% [markdown]
# ## Lecture 9 & Tutorial 10
# Applications of Hash Tables
# 1. File Systems
# 2. Online Storage
# 3. IP Adresses
#
#    عامة اي حاجة بتبقي عايز تعملها بسرعة **( انت بس هتحطها مرة ومش هتعوز تغيرها كتير )**
#
# دقيقة اجيب لك بردو جيجا تشاد يشرح لك [
# Learn Hash Tables in 13 minutes](https://youtu.be/FsfRsGFHuv4) عارفك بتحب الحاجات دي بس ده هيبسط الدنيا
# وممكن بردو القدوة ده [[Data Structures] - Hashing (Hash Table)](https://www.youtube.com/watch?v=mZFuZHOESEY&t=422s)
#
# طيب I would assume انك خدت فكرة ف همشي سريعاً كده
#
# ### Hash Functions
# A good one sshould be :
# 1. Deterministic -> same input -> same output
# 2. Fast to compute
# 3. Few collisions
# 4. Uniform distribution of keys -> عشان متكدسش في مكان واحد
#
# - Uinversal Hash Function -> **A subset of function that has a property $Pr[h(x)=h(y)\le \frac{1}{M}]$ for all possible values of x and y**
# with a load factor $\alpha=\frac{n}{m}$ ->
# 1. if low it indicate table is empty, fast lookup but waste of memor
# 2. high indicate table is full, there is multiple collisions and slow lookup but good for memory
#
# A Sweet spot is about 0.5<$\alpha$<1
# Where m is the size of hash table and n is the number of elements stored in the table
#
#
# We went further with making also dynamic hash tables and polynomial hash functions
#
# like $H_p=((ax+b)\% p)\% m$ -> $1\le a\le p-1 \ \ \ \  0\le b \le p-1$ -> **pick a,b randomly , x is  the key you are trying to hash, p is a large prime number > m**
#
# similary, for Strings
# $H_p(S)=(\sum_{i=0}^{n-1} S[i]*x^i )\% p$  -> **pick x randomly from [1,p-1] , S is the string you are trying to hash, p is a large prime number > m**
#
# finally, i would suggest this tutorial for better understanding
#
# [Tutorial](https://www.youtube.com/watch?v=p7mXY3wYdNM)
#
# [Rabin-Karp String Matching Algorithm](https://youtu.be/qQ8vS2btsxI)
#
# اخر حتة كان بيتكلم ع  Storage Optimization
# ف بدل ترفع الفايل كل مرة وتقارنه هل كان موجود ولا لا , بتعمله له هاش وبترفع الهاش
# انك تقارن هاش مع هاش اسهل بكتير من انك تقارن فايل مع فايل
# هيطلع لك شوية مشاكل وبتاع بس م علينا منها دلوقت
#
# جوجل درايف لو وقع ف منطقتك يرضيك تبقي قاعد متعطل عشان مش عارف تذاكر ؟
# ف بنجيب كذا كمبيوتر كده كل واحد مسئول عن حتة معينة  او الداتا كلها مرفوعة عليهم كل واحد فيهم عشان لو واحد وقع التاني ياخد مكانه
#
# ![](Images/Hash1.png)
# ![](Images/Hash2.png)

# %% [markdown]
# استراحة محارب🌼
#
# <img src="Images\jhin-arcana-skin-lol-splash-art-8k-wallpaper-uhdpaper.com-212@5@h.jpg" alt="description" style="width:100%; height:auto;">

# %% [markdown]
# ---

# %% [markdown]
# ## Lecture 10
#
# Application of graphs
# 1. Roads
# 2. Facebook freinds
# 3. course prequisites
# 4. web page and links ( similar to linked list)
#
# undirected -> رايح جي
# directed -> رايح بس ممكن ميبقاش فيه راجع
#
# Weighted -> Cost بدفعها اني مشيت ف الطريق ده
# Unweighted -> Cost واحد لكل الطرق
#
# Cyclic -> هل فيه نود ابدأ منها وارجع لها تاني؟ لوب
# Acyclic -> لا مفيش
#
# dense -> high number of edges
# sparse -> low number of edges
#
# simple -> no loops no multiple edges
# complete -> every node connected to every other node ( every complete graph is simple )
#
# Representation of Graphs
# 1. Adjacency Matrix -> 2D array n*n
#    - pros : easy to implement , fast to check if edge exists O(1)
#    - cons : space consuming O(n^2) , Adding/removing vertex slow O(n^2)
#
#    ![](Images/Adjancency_Matrix.png)
#
# 2. Adjacency List -> array of lists
#     - pros : space efficient O(n + m) , add edge O(load), adding vertex O(V+E)
#     - cons : slower to check if edge exists O(load)
#
#    ![](Images/Adjacency_List.png)
#
#
# 3. Incidence Matrix -> 2D array n*m
#     - pros : easy to implement , good for edge-centric algorithms
#     - cons : space consuming O(n*m) , slow to check if edge exists O(m)
#
#     ![](Images/Incidence_Matrix.png)
#
#
# Graph Traversal Algorithms : Was menteioned in Tutorial 8 so go check it out
# 1. Depth-First Search (DFS) O(E)
#    1. pre-order
#    2. post-order
#    3. in-order
# 2. Breadth-First Search (BFS) O(V+E)
# 3. Dijkstra's Algorithm for Shortest Path
#    1. Using Min-Heap (Priority Queue)
#    2. good part **fast and simple**
#    3. bad part : **fails with negative weights, and need to store large data**
#
# [Bellman Ford Algorithm](https://youtu.be/FtN3BYH2Zes)
#
# [All Pairs Shortest Path (Floyd-Warshall](https://youtu.be/FtN3BYH2Zes)

# %% [markdown]
# استراحة محارب🌼
#
# <img src="Images\jhin-arcana-skin-lol-splash-art-8k-wallpaper-uhdpaper.com-212@5@h.jpg" alt="description" style="width:100%; height:auto;">

# %% [markdown]
# ---

# %% [markdown]
# ## Lecture 11
#
# شرح لل heap
# [Heap - Heap Sort - Heapify - Priority Queues](https://youtu.be/HqPJF2L5h9U)
#
# A compelete binary tree that satisfies the heap property
# 1. Max-Heap : every node is >= its childern
# 2. Min-Heap : every node is <= its childern
#
# some of the basic operations
# 1. Insertion O(log n)
# 2. Delete O(log n)
# 3. Get Max/Min O(1) ( depnding on either max or min heap )
# 4. Extract Max/Min O(log n) ( we need to heapify after removing the root )
# 5. Build Heap O(n) ( Heapify )
#    - start from the last non-leaf node and heapify each node up to the root
# 6. Heap Sort O(n log n)
#    - build a max-heap from the input data
#    - repeat until the heap is empty:
#      - extract the maximum element from the heap
#      - place it at the end of the array
#      - heapify the root of the tree
#
# ---

# %% [markdown]
# ### B-trees
# كل الي يهمنا فيها هي الاورد غالباً بتاعها ,
# let's say that m is the order
# 1. it is a normal tree , the matter fact that each node can have at most m children and at least ceil(m/2) children ( except the root )
#
# [Understanding B-Trees: The Data Structure Behind Modern Databases
# ](https://youtu.be/K1a2Bk8NrYQ) -> should know how to insert and delete
#
# - The maximum number of items in a B-tree should be **m-1**
# - And Therefore each node should has at most m children if more then split
# - for given h height we can calculate the number of items $=m^h(m-1)$ so for all the tree just sum them $(1+m+m^2+...+m^h)\times (m-1) = m^{h+1}-1$
#
# #### Reasons for using B-trees and Comparsions
# - It may not be as deep as if it was a binary tree so we lowerd the height and therefore the number of disk accesses
# - It is more efficient for systems that read and write large blocks of data
# - Always balanced
#
#     ##### Binary Trees
#     1. حلوة وكل حاجة بس , can become unbalanced
#     2. Here comes the GOAT AVL Trees to save the day
#     3. Heaps are also good and balanced, but only for priotrization ( Max Or Min Heaps)
#
#     ##### Multi ways trees
#     1. like B-Trees , More generic since it follow the same procedure but with order of m childern
#     2. And Similar ot Hashing, it is used for storage so acessing time is fast, while deleting and inserting is slower than binary trees

# %% [markdown]
# ---

# %% [markdown]
# حمدلله ع السلامة ي ملك 👑
#
# <img src="Images\jhin-lol-lor-worldwalker-4k-wallpaper-uhdpaper.com-216@1@h.jpg" alt="description" style="width:100%; height:auto;">
